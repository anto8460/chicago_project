# %%
# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "end_to_end_project"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
import pandas as pd
import os

def load_police_data():
    csv_path = os.path.join(os.path.join("police_data"), "crimes_2012_to_2017.csv")
    return pd.read_csv(csv_path, index_col=0)

# %%
police_data = load_police_data()

# %%
police_data = police_data.loc[:, ~police_data.columns.str.contains('^Unnamed')]
police_data = police_data.drop('Location', 1)
police_data = police_data.drop('ID', 1)
police_data = police_data.drop('Case Number', 1)
police_data = police_data.drop('Block', 1)
police_data = police_data.drop('Domestic', 1)
police_data = police_data.drop('Beat', 1)
police_data = police_data.drop('FBI Code', 1)
police_data = police_data.drop('X Coordinate', 1)
police_data = police_data.drop('Y Coordinate', 1)
police_data = police_data.drop('Updated On', 1)
police_data = police_data.drop('IUCR', 1)
# Out:
# /tmp/ipykernel_243372/690973221.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('Location', 1)
# /tmp/ipykernel_243372/690973221.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('ID', 1)
# /tmp/ipykernel_243372/690973221.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('Case Number', 1)
# /tmp/ipykernel_243372/690973221.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('Block', 1)
# /tmp/ipykernel_243372/690973221.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('Domestic', 1)
# /tmp/ipykernel_243372/690973221.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('Beat', 1)
# /tmp/ipykernel_243372/690973221.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('FBI Code', 1)
# /tmp/ipykernel_243372/690973221.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('X Coordinate', 1)
# /tmp/ipykernel_243372/690973221.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('Y Coordinate', 1)
# /tmp/ipykernel_243372/690973221.py:11: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('Updated On', 1)
# /tmp/ipykernel_243372/690973221.py:12: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   police_data = police_data.drop('IUCR', 1)

# %%
police_data
# Out:
#                            Date            Primary Type  \
# 3        05/03/2016 11:40:00 PM                 BATTERY
# 89       05/03/2016 09:40:00 PM                 BATTERY
# 197      05/03/2016 11:31:00 PM  PUBLIC PEACE VIOLATION
# 673      05/03/2016 10:10:00 PM                 BATTERY
# 911      05/03/2016 10:00:00 PM                   THEFT
# ...                         ...                     ...
# 6250330  05/03/2016 11:33:00 PM                 BATTERY
# 6251089  05/03/2016 11:30:00 PM         CRIMINAL DAMAGE
# 6251349  05/03/2016 12:15:00 AM                 BATTERY
# 6253257  05/03/2016 09:07:00 PM                 BATTERY
# 6253474  05/03/2016 11:38:00 PM           OTHER OFFENSE
#
#                      Description            Location Description  Arrest  \
# 3        DOMESTIC BATTERY SIMPLE                       APARTMENT    True
# 89       DOMESTIC BATTERY SIMPLE                       RESIDENCE   False
# 197             RECKLESS CONDUCT                          STREET   False
# 673                       SIMPLE                        SIDEWALK   False
# 911               $500 AND UNDER                       RESIDENCE   False
# ...                          ...                             ...     ...
# 6250330  DOMESTIC BATTERY SIMPLE                       APARTMENT    True
# 6251089              TO PROPERTY                       APARTMENT    True
# 6251349      AGGRAVATED: HANDGUN                        SIDEWALK   False
# 6253257  DOMESTIC BATTERY SIMPLE                        SIDEWALK   False
# 6253474  OTHER WEAPONS VIOLATION  PARKING LOT/GARAGE(NON.RESID.)    True
#
#          District  Ward  Community Area  Year   Latitude  Longitude
# 3            10.0  24.0            29.0  2016  41.864073 -87.706819
# 89            3.0  20.0            42.0  2016  41.782922 -87.604363
# 197          15.0  37.0            25.0  2016  41.894908 -87.758372
# 673          15.0  28.0            25.0  2016  41.885687 -87.749516
# 911          15.0  28.0            25.0  2016  41.886297 -87.761751
# ...           ...   ...             ...   ...        ...        ...
# 6250330      10.0  28.0            30.0  2016  41.849222 -87.691556
# 6251089       7.0  17.0            69.0  2016  41.760744 -87.633335
# 6251349       8.0  15.0            66.0  2016  41.779235 -87.685207
# 6253257       4.0   7.0            46.0  2016  41.745252 -87.552773
# 6253474       3.0   6.0            69.0  2016  41.758309 -87.620658
#
# [1456714 rows x 11 columns]

# %%
police_data= police_data.dropna()
police_data
# Out:
#                            Date            Primary Type  \
# 3        05/03/2016 11:40:00 PM                 BATTERY
# 89       05/03/2016 09:40:00 PM                 BATTERY
# 197      05/03/2016 11:31:00 PM  PUBLIC PEACE VIOLATION
# 673      05/03/2016 10:10:00 PM                 BATTERY
# 911      05/03/2016 10:00:00 PM                   THEFT
# ...                         ...                     ...
# 6250330  05/03/2016 11:33:00 PM                 BATTERY
# 6251089  05/03/2016 11:30:00 PM         CRIMINAL DAMAGE
# 6251349  05/03/2016 12:15:00 AM                 BATTERY
# 6253257  05/03/2016 09:07:00 PM                 BATTERY
# 6253474  05/03/2016 11:38:00 PM           OTHER OFFENSE
#
#                      Description            Location Description  Arrest  \
# 3        DOMESTIC BATTERY SIMPLE                       APARTMENT    True
# 89       DOMESTIC BATTERY SIMPLE                       RESIDENCE   False
# 197             RECKLESS CONDUCT                          STREET   False
# 673                       SIMPLE                        SIDEWALK   False
# 911               $500 AND UNDER                       RESIDENCE   False
# ...                          ...                             ...     ...
# 6250330  DOMESTIC BATTERY SIMPLE                       APARTMENT    True
# 6251089              TO PROPERTY                       APARTMENT    True
# 6251349      AGGRAVATED: HANDGUN                        SIDEWALK   False
# 6253257  DOMESTIC BATTERY SIMPLE                        SIDEWALK   False
# 6253474  OTHER WEAPONS VIOLATION  PARKING LOT/GARAGE(NON.RESID.)    True
#
#          District  Ward  Community Area  Year   Latitude  Longitude
# 3            10.0  24.0            29.0  2016  41.864073 -87.706819
# 89            3.0  20.0            42.0  2016  41.782922 -87.604363
# 197          15.0  37.0            25.0  2016  41.894908 -87.758372
# 673          15.0  28.0            25.0  2016  41.885687 -87.749516
# 911          15.0  28.0            25.0  2016  41.886297 -87.761751
# ...           ...   ...             ...   ...        ...        ...
# 6250330      10.0  28.0            30.0  2016  41.849222 -87.691556
# 6251089       7.0  17.0            69.0  2016  41.760744 -87.633335
# 6251349       8.0  15.0            66.0  2016  41.779235 -87.685207
# 6253257       4.0   7.0            46.0  2016  41.745252 -87.552773
# 6253474       3.0   6.0            69.0  2016  41.758309 -87.620658
#
# [1418365 rows x 11 columns]

# %%
from datetime import datetime

# Time Conversion Function
def time_convert(date_time):
    s1 = date_time[:11]
    s2 = date_time[11:]
    
    month = s1[:2]
    date = s1[3:5]
    year = s1[6:10]
    
    hr = s2[:2]
    mins = s2[3:5]
    sec = s2[6:8]
    time_frame = s2[9:]
    if(time_frame == 'PM'):
        if (int(hr) != 12):
            hr = str(int(hr) + 12)
    else:
        if(int(hr) == 12):
            hr = '00'
    
    final_date = datetime(int(year), int(month), int(date), int(hr), int(mins), int(sec))
    return final_date



# Using apply() of pandas to apply time_convert on every row of the Date column
police_data['Date'] = police_data['Date'].apply(time_convert)
police_data
# Out:
# /tmp/ipykernel_243372/1915344135.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_data['Date'] = police_data['Date'].apply(time_convert)
#                        Date            Primary Type              Description  \
# 3       2016-05-03 23:40:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 89      2016-05-03 21:40:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 197     2016-05-03 23:31:00  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 673     2016-05-03 22:10:00                 BATTERY                   SIMPLE
# 911     2016-05-03 22:00:00                   THEFT           $500 AND UNDER
# ...                     ...                     ...                      ...
# 6250330 2016-05-03 23:33:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 6251089 2016-05-03 23:30:00         CRIMINAL DAMAGE              TO PROPERTY
# 6251349 2016-05-03 00:15:00                 BATTERY      AGGRAVATED: HANDGUN
# 6253257 2016-05-03 21:07:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 6253474 2016-05-03 23:38:00           OTHER OFFENSE  OTHER WEAPONS VIOLATION
#
#                    Location Description  Arrest  District  Ward  \
# 3                             APARTMENT    True      10.0  24.0
# 89                            RESIDENCE   False       3.0  20.0
# 197                              STREET   False      15.0  37.0
# 673                            SIDEWALK   False      15.0  28.0
# 911                           RESIDENCE   False      15.0  28.0
# ...                                 ...     ...       ...   ...
# 6250330                       APARTMENT    True      10.0  28.0
# 6251089                       APARTMENT    True       7.0  17.0
# 6251349                        SIDEWALK   False       8.0  15.0
# 6253257                        SIDEWALK   False       4.0   7.0
# 6253474  PARKING LOT/GARAGE(NON.RESID.)    True       3.0   6.0
#
#          Community Area  Year   Latitude  Longitude
# 3                  29.0  2016  41.864073 -87.706819
# 89                 42.0  2016  41.782922 -87.604363
# 197                25.0  2016  41.894908 -87.758372
# 673                25.0  2016  41.885687 -87.749516
# 911                25.0  2016  41.886297 -87.761751
# ...                 ...   ...        ...        ...
# 6250330            30.0  2016  41.849222 -87.691556
# 6251089            69.0  2016  41.760744 -87.633335
# 6251349            66.0  2016  41.779235 -87.685207
# 6253257            46.0  2016  41.745252 -87.552773
# 6253474            69.0  2016  41.758309 -87.620658
#
# [1418365 rows x 11 columns]

# %%
def month(x):
    return x.strftime("%-m")

police_data['Month'] = police_data['Date'].apply(month)

police_data
# Out:
# /tmp/ipykernel_243372/1191370044.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_data['Month'] = police_data['Date'].apply(month)
#                        Date            Primary Type              Description  \
# 3       2016-05-03 23:40:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 89      2016-05-03 21:40:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 197     2016-05-03 23:31:00  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 673     2016-05-03 22:10:00                 BATTERY                   SIMPLE
# 911     2016-05-03 22:00:00                   THEFT           $500 AND UNDER
# ...                     ...                     ...                      ...
# 6250330 2016-05-03 23:33:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 6251089 2016-05-03 23:30:00         CRIMINAL DAMAGE              TO PROPERTY
# 6251349 2016-05-03 00:15:00                 BATTERY      AGGRAVATED: HANDGUN
# 6253257 2016-05-03 21:07:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 6253474 2016-05-03 23:38:00           OTHER OFFENSE  OTHER WEAPONS VIOLATION
#
#                    Location Description  Arrest  District  Ward  \
# 3                             APARTMENT    True      10.0  24.0
# 89                            RESIDENCE   False       3.0  20.0
# 197                              STREET   False      15.0  37.0
# 673                            SIDEWALK   False      15.0  28.0
# 911                           RESIDENCE   False      15.0  28.0
# ...                                 ...     ...       ...   ...
# 6250330                       APARTMENT    True      10.0  28.0
# 6251089                       APARTMENT    True       7.0  17.0
# 6251349                        SIDEWALK   False       8.0  15.0
# 6253257                        SIDEWALK   False       4.0   7.0
# 6253474  PARKING LOT/GARAGE(NON.RESID.)    True       3.0   6.0
#
#          Community Area  Year   Latitude  Longitude Month
# 3                  29.0  2016  41.864073 -87.706819     5
# 89                 42.0  2016  41.782922 -87.604363     5
# 197                25.0  2016  41.894908 -87.758372     5
# 673                25.0  2016  41.885687 -87.749516     5
# 911                25.0  2016  41.886297 -87.761751     5
# ...                 ...   ...        ...        ...   ...
# 6250330            30.0  2016  41.849222 -87.691556     5
# 6251089            69.0  2016  41.760744 -87.633335     5
# 6251349            66.0  2016  41.779235 -87.685207     5
# 6253257            46.0  2016  41.745252 -87.552773     5
# 6253474            69.0  2016  41.758309 -87.620658     5
#
# [1418365 rows x 12 columns]

# %%
def hour(x):
    return x.strftime("%H")

def day(x):
    return x.strftime("%d")

police_data['Hour_Day'] = police_data['Date'].apply(hour)
police_data['Day'] = police_data['Date'].apply(day)

police_data
# Out:
# /tmp/ipykernel_243372/1303375362.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_data['Hour_Day'] = police_data['Date'].apply(hour)
# /tmp/ipykernel_243372/1303375362.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   police_data['Day'] = police_data['Date'].apply(day)
#                        Date            Primary Type              Description  \
# 3       2016-05-03 23:40:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 89      2016-05-03 21:40:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 197     2016-05-03 23:31:00  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 673     2016-05-03 22:10:00                 BATTERY                   SIMPLE
# 911     2016-05-03 22:00:00                   THEFT           $500 AND UNDER
# ...                     ...                     ...                      ...
# 6250330 2016-05-03 23:33:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 6251089 2016-05-03 23:30:00         CRIMINAL DAMAGE              TO PROPERTY
# 6251349 2016-05-03 00:15:00                 BATTERY      AGGRAVATED: HANDGUN
# 6253257 2016-05-03 21:07:00                 BATTERY  DOMESTIC BATTERY SIMPLE
# 6253474 2016-05-03 23:38:00           OTHER OFFENSE  OTHER WEAPONS VIOLATION
#
#                    Location Description  Arrest  District  Ward  \
# 3                             APARTMENT    True      10.0  24.0
# 89                            RESIDENCE   False       3.0  20.0
# 197                              STREET   False      15.0  37.0
# 673                            SIDEWALK   False      15.0  28.0
# 911                           RESIDENCE   False      15.0  28.0
# ...                                 ...     ...       ...   ...
# 6250330                       APARTMENT    True      10.0  28.0
# 6251089                       APARTMENT    True       7.0  17.0
# 6251349                        SIDEWALK   False       8.0  15.0
# 6253257                        SIDEWALK   False       4.0   7.0
# 6253474  PARKING LOT/GARAGE(NON.RESID.)    True       3.0   6.0
#
#          Community Area  Year   Latitude  Longitude Month Hour_Day Day
# 3                  29.0  2016  41.864073 -87.706819     5       23  03
# 89                 42.0  2016  41.782922 -87.604363     5       21  03
# 197                25.0  2016  41.894908 -87.758372     5       23  03
# 673                25.0  2016  41.885687 -87.749516     5       22  03
# 911                25.0  2016  41.886297 -87.761751     5       22  03
# ...                 ...   ...        ...        ...   ...      ...  ..
# 6250330            30.0  2016  41.849222 -87.691556     5       23  03
# 6251089            69.0  2016  41.760744 -87.633335     5       23  03
# 6251349            66.0  2016  41.779235 -87.685207     5       00  03
# 6253257            46.0  2016  41.745252 -87.552773     5       21  03
# 6253474            69.0  2016  41.758309 -87.620658     5       23  03
#
# [1418365 rows x 14 columns]

# %%
X = police_data[['Year', 'Month', 'Day', 'District']]
y = police_data['Primary Type']

from sklearn.model_selection import train_test_split
seed = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=seed)

X
# Out:
#          Year Month Day  District
# 3        2016     5  03      10.0
# 89       2016     5  03       3.0
# 197      2016     5  03      15.0
# 673      2016     5  03      15.0
# 911      2016     5  03      15.0
# ...       ...   ...  ..       ...
# 6250330  2016     5  03      10.0
# 6251089  2016     5  03       7.0
# 6251349  2016     5  03       8.0
# 6253257  2016     5  03       4.0
# 6253474  2016     5  03       3.0
#
# [1418365 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import cross_val_score

clf = OneVsRestClassifier(AdaBoostClassifier())
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/anton/Documents/Project_Repositories/chicago_project/chicago_project/test.ipynb Cell 11' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/home/anton/Documents/Project_Repositories/chicago_project/chicago_project/test.ipynb#ch0000010?line=4'>5</a> from sklearn.model_selection import cross_val_score
#       <a href='vscode-notebook-cell:/home/anton/Documents/Project_Repositories/chicago_project/chicago_project/test.ipynb#ch0000010?line=6'>7</a> clf = OneVsRestClassifier(AdaBoostClassifier())
# ----> <a href='vscode-notebook-cell:/home/anton/Documents/Project_Repositories/chicago_project/chicago_project/test.ipynb#ch0000010?line=7'>8</a> clf.fit(X_train, y_train)
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py:327, in OneVsRestClassifier.fit(self, X, y)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=322'>323</a> columns = (col.toarray().ravel() for col in Y.T)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=323'>324</a> # In cases where individual estimators are very fast to train setting
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=324'>325</a> # n_jobs > 1 in can results in slower performance due to the overhead
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=325'>326</a> # of spawning threads.  See joblib issue #112.
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=326'>327</a> self.estimators_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose)(
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=327'>328</a>     delayed(_fit_binary)(
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=328'>329</a>         self.estimator,
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=329'>330</a>         X,
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=330'>331</a>         column,
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=331'>332</a>         classes=[
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=332'>333</a>             "not %s" % self.label_binarizer_.classes_[i],
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=333'>334</a>             self.label_binarizer_.classes_[i],
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=334'>335</a>         ],
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=335'>336</a>     )
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=336'>337</a>     for i, column in enumerate(columns)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=337'>338</a> )
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=339'>340</a> if hasattr(self.estimators_[0], "n_features_in_"):
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=340'>341</a>     self.n_features_in_ = self.estimators_[0].n_features_in_
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=1042'>1043</a> if self.dispatch_one_batch(iterator):
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=1043'>1044</a>     self._iterating = self._original_iterator is not None
# -> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=1045'>1046</a> while self.dispatch_one_batch(iterator):
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=1046'>1047</a>     pass
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=1048'>1049</a> if pre_dispatch == "all" or n_jobs == 1:
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=1049'>1050</a>     # The iterable was consumed all at once by the above for loop.
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=1050'>1051</a>     # No need to wait for async callbacks to trigger to
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=1051'>1052</a>     # consumption.
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=858'>859</a>     return False
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=859'>860</a> else:
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=860'>861</a>     self._dispatch(tasks)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=861'>862</a>     return True
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=776'>777</a> with self._lock:
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=777'>778</a>     job_idx = len(self._jobs)
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=778'>779</a>     job = self._backend.apply_async(batch, callback=cb)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=779'>780</a>     # A job can complete so quickly than its callback is
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=780'>781</a>     # called before we get here, causing self._jobs to
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=781'>782</a>     # grow. To ensure correct results ordering, .insert is
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=782'>783</a>     # used (rather than .append) in the following line
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=783'>784</a>     self._jobs.insert(job_idx, job)
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py?line=205'>206</a> def apply_async(self, func, callback=None):
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py?line=206'>207</a>     """Schedule a func to be run"""
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py?line=207'>208</a>     result = ImmediateResult(func)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py?line=208'>209</a>     if callback:
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py?line=209'>210</a>         callback(result)
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py?line=568'>569</a> def __init__(self, batch):
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py?line=569'>570</a>     # Don't delay the application, to avoid keeping the input
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py?line=570'>571</a>     # arguments in memory
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/_parallel_backends.py?line=571'>572</a>     self.results = batch()
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=257'>258</a> def __call__(self):
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=258'>259</a>     # Set the default nested backend to self._backend but do not set the
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=259'>260</a>     # change the default number of processes to -1
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=260'>261</a>     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=261'>262</a>         return [func(*args, **kwargs)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=262'>263</a>                 for func, args, kwargs in self.items]
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=257'>258</a> def __call__(self):
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=258'>259</a>     # Set the default nested backend to self._backend but do not set the
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=259'>260</a>     # change the default number of processes to -1
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=260'>261</a>     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=261'>262</a>         return [func(*args, **kwargs)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/joblib/parallel.py?line=262'>263</a>                 for func, args, kwargs in self.items]
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/fixes.py?line=114'>115</a> def __call__(self, *args, **kwargs):
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/fixes.py?line=115'>116</a>     with config_context(**self.config):
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/fixes.py?line=116'>117</a>         return self.function(*args, **kwargs)
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py:83, in _fit_binary(estimator, X, y, classes)
#      <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=80'>81</a> else:
#      <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=81'>82</a>     estimator = clone(estimator)
# ---> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=82'>83</a>     estimator.fit(X, y)
#      <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/multiclass.py?line=83'>84</a> return estimator
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:506, in AdaBoostClassifier.fit(self, X, y, sample_weight)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=499'>500</a>     raise ValueError(
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=500'>501</a>         "Algorithm must be 'SAMME' or 'SAMME.R'."
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=501'>502</a>         f" Got {self.algorithm!r} instead."
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=502'>503</a>     )
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=504'>505</a> # Fit
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=505'>506</a> return super().fit(X, y, sample_weight)
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:160, in BaseWeightBoosting.fit(self, X, y, sample_weight)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=155'>156</a> random_state = check_random_state(self.random_state)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=157'>158</a> for iboost in range(self.n_estimators):
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=158'>159</a>     # Boosting step
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=159'>160</a>     sample_weight, estimator_weight, estimator_error = self._boost(
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=160'>161</a>         iboost, X, y, sample_weight, random_state
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=161'>162</a>     )
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=163'>164</a>     # Early termination
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=164'>165</a>     if sample_weight is None:
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:568, in AdaBoostClassifier._boost(self, iboost, X, y, sample_weight, random_state)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=528'>529</a> """Implement a single boost.
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=529'>530</a>
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=530'>531</a> Perform a single boost according to the real multi-class SAMME.R
#    (...)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=564'>565</a>     If None then boosting has terminated early.
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=565'>566</a> """
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=566'>567</a> if self.algorithm == "SAMME.R":
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=567'>568</a>     return self._boost_real(iboost, X, y, sample_weight, random_state)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=569'>570</a> else:  # elif self.algorithm == "SAMME":
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=570'>571</a>     return self._boost_discrete(iboost, X, y, sample_weight, random_state)
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py:579, in AdaBoostClassifier._boost_real(self, iboost, X, y, sample_weight, random_state)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=574'>575</a> estimator = self._make_estimator(random_state=random_state)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=576'>577</a> estimator.fit(X, y, sample_weight=sample_weight)
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=578'>579</a> y_predict_proba = estimator.predict_proba(X)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=580'>581</a> if iboost == 0:
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/ensemble/_weight_boosting.py?line=581'>582</a>     self.classes_ = getattr(estimator, "classes_", None)
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py:1002, in DecisionTreeClassifier.predict_proba(self, X, check_input)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=977'>978</a> """Predict class probabilities of the input samples X.
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=978'>979</a>
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=979'>980</a> The predicted class probability is the fraction of samples of the same
#    (...)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=998'>999</a>     classes corresponds to that in the attribute :term:`classes_`.
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=999'>1000</a> """
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=1000'>1001</a> check_is_fitted(self)
# -> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=1001'>1002</a> X = self._validate_X_predict(X, check_input)
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=1002'>1003</a> proba = self.tree_.predict(X)
#    <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=1004'>1005</a> if self.n_outputs_ == 1:
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py:471, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=468'>469</a> """Validate the training data on predict (probabilities)."""
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=469'>470</a> if check_input:
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=470'>471</a>     X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=471'>472</a>     if issparse(X) and (
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=472'>473</a>         X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=473'>474</a>     ):
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/tree/_classes.py?line=474'>475</a>         raise ValueError("No support for np.int64 index based sparse matrices")
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/base.py:577, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/base.py?line=574'>575</a>     raise ValueError("Validation should be done on X, y or both.")
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/base.py?line=575'>576</a> elif not no_val_X and no_val_y:
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/base.py?line=576'>577</a>     X = check_array(X, input_name="X", **check_params)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/base.py?line=577'>578</a>     out = X
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/base.py?line=578'>579</a> elif no_val_X and not no_val_y:
#
# File ~/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=853'>854</a>         array = array.astype(dtype, casting="unsafe", copy=False)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=854'>855</a>     else:
# --> <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=855'>856</a>         array = np.asarray(array, order=order, dtype=dtype)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=856'>857</a> except ComplexWarning as complex_warning:
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=857'>858</a>     raise ValueError(
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=858'>859</a>         "Complex data not supported\n{}\n".format(array)
#     <a href='file:///home/anton/Documents/Project_Repositories/chicago_project/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py?line=859'>860</a>     ) from complex_warning
#
# KeyboardInterrupt:
